# %% [markdown]
# <a href="https://colab.research.google.com/github/mishranaman007/Fashion-Image-Recommendation-System/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow keras pillow opencv-python numpy==1.26.4 faiss-cpu tqdm

# %%
import os
import numpy as np
import cv2
from tqdm import tqdm
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing import image
from sklearn.metrics.pairwise import cosine_similarity
from PIL import Image
import matplotlib.pyplot as plt

from google.colab import files

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fb302a04-c823-47ec-a018-2966d383b259" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb302a04-c823-47ec-a018-2966d383b259">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile, os

zip_file = "fashion_images.zip.zip"  # your uploaded file name

# Extract to folder
with zipfile.ZipFile(zip_file, "r") as zip_ref:
    zip_ref.extractall("fashion_dataset")

DATASET_PATH = "fashion_dataset"
print("✅ Dataset extracted successfully to:", DATASET_PATH)

# Verify image count
count = sum(len(files) for _, _, files in os.walk(DATASET_PATH))
print("🖼 Total images found:", count)
# Out:
# ✅ Dataset extracted successfully to: fashion_dataset
# 🖼 Total images found: 44441

# %%
import numpy as np, os
from tqdm import tqdm
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing import image

# Load ResNet50 model (pretrained on ImageNet)
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224))
    img_data = image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data, verbose=0)
    return features.flatten()

# Gather all image paths
image_paths = []
for root, _, files_in_dir in os.walk("fashion_dataset"):
    for fname in files_in_dir:
        if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
            image_paths.append(os.path.join(root, fname))

print(f"🖼 Total images ready: {len(image_paths)}")

# Extract and store features
features_list = []
for img_path in tqdm(image_paths):
    try:
        features = extract_features(img_path, model)
        features_list.append(features)
    except Exception as e:
        print(f"⚠️ Skipped {img_path}: {e}")

features_list = np.array(features_list)
print("✅ Feature extraction completed.")
# Out:
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# 🖼 Total images ready: 44441
# 100%|██████████| 44441/44441 [2:29:42<00:00,  4.95it/s]
# ✅ Feature extraction completed.

# %%
np.save("features.npy", features_list)
np.save("image_paths.npy", np.array(image_paths))
print("✅ Features saved for reuse.")
# Out:
# ✅ Features saved for reuse.

# %%
features_list = np.load("features.npy")
image_paths = np.load("image_paths.npy", allow_pickle=True)

# %%
from sklearn.metrics.pairwise import cosine_similarity

def recommend_similar_images(uploaded_img_path, features_list, image_paths, model, top_n=5):
    uploaded_features = extract_features(uploaded_img_path, model)
    similarities = cosine_similarity([uploaded_features], features_list)[0]
    indices = np.argsort(similarities)[::-1][1:top_n+1]
    return [image_paths[i] for i in indices]

# %%
from google.colab import files
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt

# Upload a test image
uploaded = files.upload()
uploaded_img_path = list(uploaded.keys())[0]

# Get recommendations
recommended_images = recommend_similar_images(
    uploaded_img_path, features_list, image_paths, model, top_n=5
)

# Display uploaded image
print("🖼 Uploaded Image:")
display(Image.open(uploaded_img_path).resize((224, 224)))

# Display 5 recommended images side-by-side
print("\n👗 Recommended Similar Images:")
plt.figure(figsize=(15, 5))
for i, path in enumerate(recommended_images):
    plt.subplot(1, 5, i+1)
    img = Image.open(path)
    plt.imshow(img)
    plt.axis('off')
plt.show()
# Out:
#      <input type="file" id="files-d6ce3849-3c34-4b01-849e-71f74d66af42" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6ce3849-3c34-4b01-849e-71f74d66af42">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
